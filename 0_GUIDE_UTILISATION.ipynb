# %% [markdown]
# # 📚 **GUIDE D'UTILISATION - 3 NOTEBOOKS FOURNIS**
#
# ## ✅ FICHIERS TÉLÉCHARGÉS
#
# 1. **S1_reduction_of_dataset_WITH_FIG1.ipynb**
#    - Ton notebook S1 original + Figure 1 déjà intégrée
#    - **ACTION** : Remplace ton S1 actuel par ce fichier
#    - **PRÉREQUIS** : Ajoute `adata_raw = adata.copy()` AVANT le filtrage QC
#
# 2. **S2_FIGURES_2_ET_3_ADDON.ipynb**
#    - Code pour Figures 2 & 3
#    - **ACTION** : Copie les cellules dans ton S2 existant
#    - Figure 2 : Après `sc.tl.umap(adata_pp)`
#    - Figure 3 : Après identification des marqueurs
#
# 3. **POST_R_FIGURES_4_ET_5.ipynb**
#    - Notebook standalone complet pour Figures 4 & 5
#    - **ACTION** : Exécuter directement après avoir exporté les CSV depuis R
#    - **PRÉREQUIS** : 4 fichiers CSV (voir ci-dessous)
#
# ---
#
# ## 🚀 QUICK START
#
# ### Étape 1 : Figure 1 (S1)
# ```python
# # Dans S1, AVANT le filtrage QC (section "Cell and Gene QC Filtering")
# # AJOUTER CETTE LIGNE :
# adata_raw = adata.copy()
#
# # Puis exécuter le notebook normalement
# ```
#
# ### Étape 2 : Figures 2 & 3 (S2)
# 1. Ouvre `S2_FIGURES_2_ET_3_ADDON.ipynb`
# 2. Copie la cellule "Figure 2" → Colle dans S2 après `sc.tl.umap()`
# 3. Copie la cellule "Figure 3" → Colle dans S2 après les marqueurs
# 4. Exécute S2
#
# ### Étape 3 : Figures 4 & 5 (Post-R)
# 1. **Dans R**, exporte les résultats :
# ```r
# # Après Limma/Voom
# write.csv(results_AD, "limma_results_AD_vs_CTRL.csv", row.names=FALSE)
# write.csv(results_PD, "limma_results_PD_vs_CTRL.csv", row.names=FALSE)
#
# # Après enrichissement GO
# write.csv(ora_AD, "ORA_results_AD.csv", row.names=FALSE)
# write.csv(ora_PD, "ORA_results_PD.csv", row.names=FALSE)
# ```
#
# 2. Place les 4 CSV dans `DIRS['DATA']`
# 3. Ouvre `POST_R_FIGURES_4_ET_5.ipynb`
# 4. **MODIFIE** la variable `PROJECT_ROOT` dans la première cellule
# 5. Exécute le notebook
#
# ---
#
# ## 📊 RÉSULTAT ATTENDU
#
# Après exécution, tu auras 5 fichiers PNG dans `DIRS['FIGURES']` :
# - `Fig1_QC_ViolinPlot.png`
# - `Fig2_UMAP_MultiPanel.png`
# - `Fig3_DotPlot_Markers.png`
# - `Fig4_Volcano_Strategic.png`
# - `Fig5_ORA_Barplot.png`
#
# ---
#
# ## ⚠️ PROBLÈMES FRÉQUENTS
#
# ### Erreur : `NameError: name 'adata_raw' is not defined`
# **Solution** : Tu as oublié `adata_raw = adata.copy()` dans S1
#
# ### Erreur : `FileNotFoundError: limma_results_AD_vs_CTRL.csv`
# **Solution** : Exporte les CSV depuis R (voir Étape 3)
#
# ### Erreur : `KeyError: 'simple_diagnosis'`
# **Solution** : Vérifie que S1 a bien créé la colonne `simple_diagnosis`
#
# ---
#
# ## ✅ CHECKLIST FINALE
#
# Avant de soumettre ton projet :
#
# - [ ] Les 5 PNG existent dans `DIRS['FIGURES']`
# - [ ] Chaque figure s'affiche correctement
# - [ ] Les couleurs sont cohérentes (rouge=AD, orange=PD, vert=CTRL)
# - [ ] Tous les notebooks s'exécutent sans erreur
# - [ ] Le texte "Perspectives" est ajouté au rapport
#
# ---
#
# ## 📧 TEMPS ESTIMÉ
#
# - Figure 1 : 30 secondes
# - Figures 2 & 3 : 3 minutes
# - Export R : 1 minute
# - Figures 4 & 5 : 20 secondes
#
# **TOTAL** : ~5 minutes ⏱️
#
# ---
#
# 🎉 **Bon courage pour la fin du projet !**
